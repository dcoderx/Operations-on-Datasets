# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Pokemon_data.csv")

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
(df[['Name', 'Type 1', 'HP']])
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
for index, row in df.iterrows():
    print(index, row['Type 1'])
# Out:
# 0 Grass
# 1 Grass
# 2 Grass
# 3 Grass
# 4 Fire
# 5 Fire
# 6 Fire
# 7 Fire
# 8 Fire
# 9 Water
# 10 Water
# 11 Water
# 12 Water
# 13 Bug
# 14 Bug
# 15 Bug
# 16 Bug
# 17 Bug
# 18 Bug
# 19 Bug
# 20 Normal
# 21 Normal
# 22 Normal
# 23 Normal
# 24 Normal
# 25 Normal
# 26 Normal
# 27 Normal
# 28 Poison
# 29 Poison
# 30 Electric
# 31 Electric
# 32 Ground
# 33 Ground
# 34 Poison
# 35 Poison
# 36 Poison
# 37 Poison
# 38 Poison
# 39 Poison
# 40 Fairy
# 41 Fairy
# 42 Fire
# 43 Fire
# 44 Normal
# 45 Normal
# 46 Poison
# 47 Poison
# 48 Grass
# 49 Grass
# 50 Grass
# 51 Bug
# 52 Bug
# 53 Bug
# 54 Bug
# 55 Ground
# 56 Ground
# 57 Normal
# 58 Normal
# 59 Water
# 60 Water
# 61 Fighting
# 62 Fighting
# 63 Fire
# 64 Fire
# 65 Water
# 66 Water
# 67 Water
# 68 Psychic
# 69 Psychic
# 70 Psychic
# 71 Psychic
# 72 Fighting
# 73 Fighting
# 74 Fighting
# 75 Grass
# 76 Grass
# 77 Grass
# 78 Water
# 79 Water
# 80 Rock
# 81 Rock
# 82 Rock
# 83 Fire
# 84 Fire
# 85 Water
# 86 Water
# 87 Water
# 88 Electric
# ...

# %%
df.loc[df['Type 2'] == 'Flying']
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard      Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 15    12                 Butterfree       Bug  Flying   60      45       50
# 20    16                     Pidgey    Normal  Flying   40      45       40
# 21    17                  Pidgeotto    Normal  Flying   63      60       55
# ..   ...                        ...       ...     ...  ...     ...      ...
# 730  662                Fletchinder      Fire  Flying   62      73       55
# 731  663                 Talonflame      Fire  Flying   78      81       71
# 734  666                   Vivillon       Bug  Flying   80      52       50
# 771  701                   Hawlucha  Fighting  Flying   78      92       75
# 793  717                    Yveltal      Dark  Flying  126     131       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values(['Attack' , 'Defense'], ascending = [1,1])
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
# 261  242                  Blissey   Normal       NaN  255      10       10
# 139  129                 Magikarp    Water       NaN   20      10       55
# 230  213                  Shuckle      Bug      Rock   20      10      230
# ..   ...                      ...      ...       ...  ...     ...      ...
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Overall Strength'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] +df['Speed']

#OR

#df['Overall Strength'] = df.iloc[:, 4:10].sum(axis = 1)

# %%
# To delete the columns below .

#df = df.drop(columns=[ 'Type 1', 'Type 2', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'])

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Overall Strength
# 0       65     45           1      False               318
# 1       80     60           1      False               405
# 2      100     80           1      False               525
# 3      120     80           1      False               625
# 4       50     65           1      False               309

# %%
# to move columns

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head()
# Out:
#    #                   Name Type 1  Type 2  Overall Strength  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison               318  45      49
# 1  2                Ivysaur  Grass  Poison               405  60      62
# 2  3               Venusaur  Grass  Poison               525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison               625  80     100
# 4  4             Charmander   Fire     NaN               309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       49       65       65     45           1      False
# 1       63       80       80     60           1      False
# 2       83      100      100     80           1      False
# 3      123      122      120     80           1      False
# 4       43       60       50     65           1      False

# %%
df = df.sort_values('Overall Strength', ascending = True)

# %%
from openpyxl.workbook import Workbook

# %%
# to save database

#df.to_csv('Mikes-Edited.csv') 

#OR

df.to_excel('Mikes-Edited.xlsx', index = False)

# %%
# FILTERING DATA

# %%
df.loc[(df['Overall Strength'] > 700)]

# Creating new data set 

Strong_pokemons = df.loc[(df['Overall Strength'] > 700)]
Strong_pokemons = Strong_pokemons.reset_index(drop = True)
Strong_pokemons.head()

# Saving new data

#Strong_pokemons.to_excel('Mikes Strong pokemons.xlsx')
# Out:
#      #                   Name   Type 1  Type 2  Overall Strength   HP  Attack  \
# 0  493                 Arceus   Normal     NaN               720  120     120
# 1  383  GroudonPrimal Groudon   Ground    Fire               770  100     180
# 2  382    KyogrePrimal Kyogre    Water     NaN               770  100     150
# 3  150    MewtwoMega Mewtwo Y  Psychic     NaN               780  106     150
# 4  384  RayquazaMega Rayquaza   Dragon  Flying               780  105     180
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      120      120      120    120           4       True
# 1      160      150       90     90           3       True
# 2       90      180      160     90           3       True
# 3       70      194      120    140           1       True
# 4      100      180      100    115           3       True

# %%
#df.loc[df['Name'].str.contains('Mega')]

# for not
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                   Name  Type 1  Type 2  Overall Strength   HP  \
# 206  191                Sunkern   Grass     NaN               180   30
# 322  298                Azurill  Normal   Fairy               190   50
# 446  401              Kricketot     Bug     NaN               194   37
# 288  265                Wurmple     Bug     NaN               195   45
# 16    13                 Weedle     Bug  Poison               195   40
# ..   ...                    ...     ...     ...               ...  ...
# 711  646     KyuremBlack Kyurem  Dragon     Ice               700  125
# 712  646     KyuremWhite Kyurem  Dragon     Ice               700  125
# 552  493                 Arceus  Normal     NaN               720  120
# 424  383  GroudonPrimal Groudon  Ground    Fire               770  100
# 422  382    KyogrePrimal Kyogre   Water     NaN               770  100
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#Filtering out data in the ORIGINAL DATASET , where Type 1 is either fire or water.

import re
df.loc[df['Type 1'].str.contains('fire|water' , flags = re.I , regex = True)]
# Out:
#        #                   Name Type 1  Type 2  Overall Strength   HP  Attack  \
# 139  129               Magikarp  Water     NaN               200   20      10
# 381  349                 Feebas  Water     NaN               200   20      15
# 209  194                 Wooper  Water  Ground               210   55      45
# 293  270                  Lotad  Water   Grass               220   40      30
# 236  218                 Slugma   Fire     NaN               250   40      40
# ..   ...                    ...    ...     ...               ...  ...     ...
# 141  130  GyaradosMega Gyarados  Water    Dark               640   95     155
# 421  382                 Kyogre  Water     NaN               670  100     100
# 541  484                 Palkia  Water  Dragon               680   90     120
# 270  250                  Ho-oh   Fire  Flying               680  106     130
# 422  382    KyogrePrimal Kyogre  Water     NaN               770  100     150
#
# ...

# %%
# Aggregate statistics

df = pd.read_csv('Mikes-Edited.csv')

# %%
df.groupby(['Type 1']).mean().sort_values('HP', ascending = False)
# Out:
#           Unnamed: 0           #  Overall Strength         HP      Attack  \
# Type 1
# Dragon    521.843750  474.375000        550.531250  83.312500  112.125000
# Normal    351.581633  319.173469        401.683673  77.275510   73.469388
# Fairy     494.529412  449.529412        413.176471  74.117647   61.529412
# Ground    392.312500  356.281250        437.500000  73.781250   95.750000
# Water     333.312500  303.089286        430.455357  72.062500   74.151786
# Ice       465.666667  423.541667        433.458333  72.000000   72.750000
# Flying    746.500000  677.750000        485.000000  70.750000   78.750000
# Psychic   420.105263  380.807018        475.947368  70.631579   71.456140
# Fire      360.942308  327.403846        458.076923  69.903846   84.769231
# Fighting  400.444444  363.851852        416.444444  69.851852   96.777778
# Grass     380.414286  344.871429        421.142857  67.271429   73.214286
# Poison    278.285714  251.785714        399.142857  67.250000   74.678571
# ...

# %%
#df['count'] = 1

df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
